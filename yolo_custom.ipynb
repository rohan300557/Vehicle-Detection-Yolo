# %% [markdown]
# # Training Custom YOLOv3 for Vehicle Detection

# %% [markdown]
# ### Mounting drive and navigating to the “Project” folder in the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/College Training 6th Sem/Project'
# Out:
# /content/drive/MyDrive/College Training 6th Sem/Project

# %% [markdown]
# ### Clone Darknet git repository

# %%
# !git clone https://github.com/AlexeyAB/darknet

# %%
# %cd darknet
# Out:
# /content/drive/MyDrive/College Training 6th Sem/Project/darknet

# %% [markdown]
# ### Make changes in the makefile to enable OPENCV, GPU and CUDNN.
# * By setting the OPENCV, GPU and CUDNN to 1.

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

# %% [markdown]
# ### Run make command to build darknet
#  * "!make" will create a ready to go configured algorithm

# %%
# %%time
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:935:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1136:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd ..
# Out:
# /content/drive/My Drive/College Training 6th Sem/Project

# %% [markdown]
# ### Creating “laballed.data” and “classes.names” files

# %%
# !python creating-files-data-and-name.py

# %% [markdown]
# ### Creating the files train.txt & test.txt

# %%
# !python creating-train-and-test-txt-files.py

# %% [markdown]
# ### Making the list of train data into train.txt file

# %%
from glob import glob
imgs_list1 = glob("training_image/*jpg")
imgs_list2 = glob("training_image/*jpeg")
imgs_list = imgs_list1+imgs_list2
file = open("training_image/train.txt",'w')
file.write("\n".join(imgs_list))
file.close()

# %%
# !ls
# Out:
#  backup				       'data labelling.ipynb'
#  creating-files-data-and-name.py       'Links File.gsheet'
#  creating-train-and-test-txt-files.py  'Not Real one vehicle_detection.ipynb'
#  custom_weight			        training_image
#  darknet			        Untitled0.ipynb

# %% [markdown]
# Run the following code to avoid being kicked off Colab VM.
# *  Press `Ctrl + Shift + i`
# * Go to console
# * Paste the following code
# * Press Enter.
#
# ```
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)
# ClickConnect()
# ```

# %% [markdown]
# ### Training YOLOv3 Darknet model

# %%
# %%time.
# !darknet/darknet detector train training_image/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 235951, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.892702), count: 4, class_loss = 0.024773, iou_loss = 0.032565, total_loss = 0.057338
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 235955, rewritten_bbox = 0.000000 %
# ...
